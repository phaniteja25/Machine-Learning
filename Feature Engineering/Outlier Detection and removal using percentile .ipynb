# %%
import pandas as pd
data = pd.read_csv('AB_NYC_2019.csv')

# %%
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
data.shape
# Out:
# (48895, 16)

# %%
max_price = data['price'].quantile(0.95)

# %%
min_price = data['price'].quantile(0.05)

# %%
data[data['price']<min_price]
# Out:
#              id                                              name    host_id  \
# 36        11452                       Clean and Quiet in Brooklyn       7355
# 249       62452                    A SpeciaL!! Private Room in NY     303939
# 250       62461                       B NYC Staten Alternative...     303939
# 251       62787                       C Private Room By The Ferry     303939
# 256       63320                D Private Che@p Room 2 Explore NYC     303939
# ...         ...                                               ...        ...
# 48851  36455649  #7 New Hotel-Like Private Room KING bed near JFK  263504959
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
# 48867  36473044   The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                      Heaven for you(only for guy)  261338177
# 48871  36475746     A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
#
# ...

# %%
data[data['price']>max_price]
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 121       27659                   3 Story Town House in Park Slope     119588
# 158       38663                   Luxury Brownstone in Boerum Hill     165789
# ...         ...                                                ...        ...
# 48748  36417250                 US Open special 2-bed luxury condo  133288905
# 48755  36419291  Wyndham Midtown 45 New York City 1 Bedroom Deluxe  273812306
# 48757  36419574     Luxury & Spacious 1500 ft² MANHATTAN Townhouse   11454384
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
# ...

# %%
df = data[(min_price<data['price']) & (data['price']<max_price)]

# %%
df
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# ...         ...                                                ...        ...
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
df.shape
# Out:
# (43631, 16)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.363100e+04  4.363100e+04  43631.000000  43631.000000  43631.000000
# mean   1.874542e+07  6.494019e+07     40.729397    -73.952633    128.201187
# std    1.097545e+07  7.726130e+07      0.054071      0.045249     70.515988
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     41.000000
# 25%    9.218810e+06  7.362414e+06     40.690500    -73.982890     72.000000
# 50%    1.932280e+07  2.869966e+07     40.723110    -73.955730    109.000000
# 75%    2.878742e+07  1.020121e+08     40.763615    -73.937710    169.000000
# max    3.648724e+07  2.743213e+08     40.911690    -73.712990    353.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    43631.000000       43631.000000       35092.000000
# mean         6.850359          24.227017           1.382010
# std         20.148614          45.666488           1.690541
# ...

# %% [markdown]
# ### Outlier Detection using Z Score

# %%
import matplotlib.pyplot as plt

plt.hist(data['number_of_reviews'], bins=20, edgecolor='black')

# Adding titles and labels
plt.title('Histogram of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Display the plot
plt.show()
